# %%
#### import library for kinect
import cv2
from pykinect2 import PyKinectV2
from pykinect2 import PyKinectRuntime
import numpy as np
import datetime
import scipy.io 
import timeit

# %%
import argparse
import os
import sys
import time
import json
import numpy as np
import torch
import torch.nn as nn
import torch.nn.parallel
from torch.autograd import Variable
import torch.backends.cudnn as cudnn
import torch.utils.data
from sklearn.metrics import confusion_matrix
from data_loader_jpeg import VideoFolder
from model import ConvColumn
from torchvision.transforms import *
from PIL import Image
gpus = [0,0]
best_prec1 = int(0)

# %%
 # set run output folder
model_name = "jester_conv_example"
start = time.time()
# create model
model = ConvColumn(7)

# multi GPU setting
model = torch.nn.DataParallel(model, device_ids= gpus).cuda()

if os.path.isfile("checkpoint.pth.tar"):
    print("=> loading checkpoint")
    checkpoint = torch.load("checkpoint.pth.tar")
    start_epoch = checkpoint['epoch']
    best_prec1 = checkpoint['best_prec1']
    model.load_state_dict(checkpoint['state_dict'])
    print("=> loaded checkpoint (epoch {})"
          .format(checkpoint['epoch']))
else:
    print("=> no checkpoint found ")

cudnn.benchmark = False
print(time.time() - start)
# Out:
# => loading checkpoint
# => loaded checkpoint (epoch 51)
# 2.760035276412964

# %%
class GestureBrain():
    
    def __init__(self,  model ):
        self.curr_stream = []
        self.model = model 
        self.counter  = 0 

    def adjust_judge_sequence(self):
        frame_diff = len(self.curr_stream) - 18 
        if  frame_diff == 0 :
            return self.curr_stream
        elif frame_diff > 0 :
            return self.curr_stream[frame_diff:]
        else :
            return self.curr_stream[:1] * abs(frame_diff) + self.curr_stream

    def prepreocess_img (self,  img_array):
        
        img_array = (img_array / 255.)
        img_array  = cv2.resize(img_array ,(84,84), interpolation = cv2.INTER_CUBIC)
        img_array = np.array(img_array, dtype=np.float32)
        
        transform = Compose([
        ToTensor(),
        Normalize(mean=[0.485, 0.456, 0.406],
                  std=[0.229, 0.224, 0.225])
        ])
        
        img_array = transform(img_array)
        return (img_array)
    

    def push_img (self, img):

        img = self.prepreocess_img(img )
        self.curr_stream.append(torch.unsqueeze(img, 0))
        if len( self.curr_stream ) > 18 :      ## limit 18 frames
            self.curr_stream.pop(0)

            
    def regonize(self):
        
        self.curr_stream = self.adjust_judge_sequence()
        data = torch.cat(self.curr_stream)
        data = data.permute(1, 0, 2, 3)
        data = data.unsqueeze(0)
        input = data
        
        input_vars = Variable(input)
        output = model(input_vars)
        _, predicted = torch.max(output.data, 1)
        predicted = predicted.cpu().numpy()
        predicted = predicted[0]
        gestures = ['Swiping_Left', 'Swiping_Right', 'Swiping_Down', 'Swiping_Up', 'Zooming_In', 'Zooming_Out', 'Doing_other_things']
        print('predict_gesture: {}'.format(gestures[predicted]))
        index = predicted
        #self.curr_stream = []
        if index != 6 :
            print("cleaning!")
            self.curr_stream = []         
        return index

# %%
# get frame by  Kinect
kinect = PyKinectRuntime.PyKinectRuntime(PyKinectV2.FrameSourceTypes_Color | PyKinectV2.FrameSourceTypes_Body)
print(type(kinect))

# Get one color picture frame
cv2.namedWindow('Color Image', cv2.WINDOW_NORMAL)
cv2.resizeWindow('Color Image', int(1920/2), int(1080/2))

frame = None
cnt = 0
x0 = 500
y0 = 500
blue_color = (255,0,0)

def draw_rectangle(img, x0, y0, color):
    # ok, at least one is good 
    w = 406
    h = 406
    s1 = (int(x0 - w),int(y0 + h))      #### note: may be  transfer x to y
    s2 = (int(x0 + w),int(y0 + h))
    s3 = (int(x0 + w),int(y0 - h))
    s4 = (int(x0 - w),int(y0 - h))
    cv2.line(img,s1,s2,color,5)
    cv2.line(img,s2,s3,color,5)
    cv2.line(img,s3,s4,color,5)
    cv2.line(img,s4,s1,color,5)

counter = 0 
gb = GestureBrain(model)
while(True):

#     colorFrame = kinect.get_last_color_frame()
#     colorFrame = colorFrame.reshape((1080,1920,4))
#     cv2.imshow("Color Image", colorFrame)
    start = timeit.default_timer()  
    # gb = GestureBrain(model)
    
    if (kinect.has_new_body_frame()): 
        bodies = kinect.get_last_body_frame()
        if bodies is not None: 
            
            for i in range(0, kinect.max_body_count):
                body = bodies.bodies[i]      ##### set i =1 ???
                if not body.is_tracked: 
                    continue
                joints = body.joints
                # convert joint coordinates to color space 
                joint_points = kinect.body_joints_to_color_space(joints)     ### joint in color spaces
                joint0 = PyKinectV2.JointType_SpineShoulder
                x0 = joint_points[joint0].x
                y0 = joint_points[joint0].y  
                
                #### convert to RGB frames
                colorFrame = kinect.get_last_color_frame()
                colorFrame = colorFrame.reshape((1080,1920,4))
                rgb_frame = colorFrame[:,:,:-1]
                
                
                ######## draw block
                draw_rectangle(colorFrame, x0, y0, blue_color)
                cv2.imshow("Color Image", colorFrame)       
                
                ########### boclk frame (note: may be change x,y)
                w1 = 400
                h1 = 400
                cnt = cnt + 1                        

                    
                roi_frame = rgb_frame[int(y0- h1):int(y0 + h1),int(x0 -w1):int(x0 + w1),:]
                counter += 1

                gb.push_img(roi_frame)
                
#                 if counter != 18 :
#                     continue 
#                 else:
#                     counter = 0 
                
                action = gb.regonize()

        
                path = 'D:\\Hand_Gesture_Recognition_System\\RGB_Output'
                fmtname = datetime.datetime.today().strftime("%y%m%d_%H%M%S")
#                cv2.imwrite('{}\\Color_{}_roi_{}.png'.format(path, fmtname, cnt), roi_frame)
                pass
 
    key = cv2.waitKey(10)
    if  key == 27:
        break
    stop = timeit.default_timer()
    fps = 1/(stop-start)
    
    print("Estimated fps : {0}".format(fps))
cv2.destroyAllWindows()
kinect.close()
# Out:
# <class 'pykinect2.PyKinectRuntime.PyKinectRuntime'>
# Estimated fps : 82.60406484962405
# Estimated fps : 84.53673022819632
# Estimated fps : 85.5217719178749
# Estimated fps : 84.2470404984424
# Estimated fps : 80.13012262387741
# Estimated fps : 85.01097811630999
# Estimated fps : 85.41580213319082
# Estimated fps : 81.58994174847406
# Estimated fps : 78.57558893209959
# Estimated fps : 80.55609275468586
# Estimated fps : 78.46860701292316
# Estimated fps : 88.97398324602025
# Estimated fps : 84.81818620473342
# Estimated fps : 81.30313822529547
# Estimated fps : 82.48971116168848
# Estimated fps : 78.5562755569459
# Estimated fps : 81.16236494597828
# Estimated fps : 75.7531728759511
# Estimated fps : 80.98288491661287
# Estimated fps : 85.4843408063025
# Estimated fps : 90.0750448373047
# Estimated fps : 82.40656790586495
# Estimated fps : 85.25217032833784
# Estimated fps : 83.94128742657973
# Estimated fps : 83.21409297481549
# Estimated fps : 84.04965573300188
# Estimated fps : 76.20142621813777
# Estimated fps : 82.29083376246429
# Estimated fps : 86.504490539111
# Estimated fps : 84.64664242891173
# Estimated fps : 79.07219810620532
# Estimated fps : 79.2540183502785
# Estimated fps : 81.6676500650434
# Estimated fps : 88.68892532795186
# Estimated fps : 81.94748374163768
# Estimated fps : 81.89975772259265
# Estimated fps : 89.41525509944474
# Estimated fps : 91.43378413524114
# Estimated fps : 78.1494020361887
# Estimated fps : 83.37196452286089
# Estimated fps : 85.35566184325532
# Estimated fps : 85.72823038845134
# Estimated fps : 86.05348313506676
# Estimated fps : 81.81970303481656
# Estimated fps : 81.93984384104444
# Estimated fps : 81.17173466324968
# Estimated fps : 82.15430093706905
# Estimated fps : 85.6300906079501
# Estimated fps : 81.91884145773146
# Estimated fps : 84.54282897268186
# Estimated fps : 88.93122027724311
# Estimated fps : 82.80641134350893
# Estimated fps : 81.48215361794831
# Estimated fps : 85.50305226548677
# Estimated fps : 85.97982342439265
# Estimated fps : 82.82396871392534
# Estimated fps : 79.47618401718056
# Estimated fps : 85.95880094867805
# Estimated fps : 85.49057704933935
# Estimated fps : 82.78691188244731
# Estimated fps : 80.26916754189708
# Estimated fps : 78.74807364931472
# Estimated fps : 81.46893611104657
# Estimated fps : 85.5863135087766
# Estimated fps : 85.73659309840272
# Estimated fps : 74.23673374580264
# Estimated fps : 82.7012232415904
# Estimated fps : 89.57244770567371
# Estimated fps : 84.97810060187078
# Estimated fps : 84.60793704274226
# Estimated fps : 83.24561943549953
# Estimated fps : 84.72824331815015
# Estimated fps : 78.09385134834942
# Estimated fps : 82.98819724759856
# Estimated fps : 78.75160163075218
# Estimated fps : 79.01177660411253
# Estimated fps : 81.00154370766263
# Estimated fps : 85.95669926650324
# Estimated fps : 79.18440019820626
# Estimated fps : 76.0103130675424
# Estimated fps : 83.10393816187586
# Estimated fps : 84.94730101966891
# Estimated fps : 81.33135150141202
# Estimated fps : 78.70223863890797
# Estimated fps : 82.9921153891548
# Estimated fps : 86.22443774066282
# Estimated fps : 86.12515923566984
# Estimated fps : 72.85069832981053
# Estimated fps : 88.7919634288031
# Estimated fps : 84.90421909339086
# Estimated fps : 80.02979808327095
# Estimated fps : 82.52262804563104
# Estimated fps : 77.81727832130629
# Estimated fps : 85.19432462559915
# Estimated fps : 88.69787566858405
# Estimated fps : 78.49313447498335
# Estimated fps : 84.28137511087685
# Estimated fps : 76.31059257651472
# Estimated fps : 76.76381064675394
# Estimated fps : 81.81018313824947
# Estimated fps : 84.94524850798521
# Estimated fps : 85.24803588748773
# Estimated fps : 88.20827478924038
# Estimated fps : 78.58612750357595
# Estimated fps : 82.0067413109409
# Estimated fps : 82.43941845468342
# Estimated fps : 84.98837209302405
# Estimated fps : 84.97399270055337
# Estimated fps : 85.43448359659769
# Estimated fps : 84.37442100463134
# Estimated fps : 86.47470175870126
# Estimated fps : 80.12829629629596
# Estimated fps : 87.94789112923428
# Estimated fps : 81.8425598286613
# Estimated fps : 76.18161133743567
# Estimated fps : 82.37374352726198
# Estimated fps : 91.61725692544363
# Estimated fps : 81.56911832946633
# Estimated fps : 76.05306537446562
# Estimated fps : 83.65366677770915
# Estimated fps : 83.27322469089154
# Estimated fps : 81.60509273229452
# Estimated fps : 81.70561030026929
# Estimated fps : 78.83460029151203
# Estimated fps : 81.09683744319574
# Estimated fps : 84.11400612498907
# Estimated fps : 84.98426319860677
# Estimated fps : 85.66138739309415
# Estimated fps : 89.28354835432908
# Estimated fps : 77.69689268034055
# Estimated fps : 92.94212975202305
# Estimated fps : 79.40438170525164
# Estimated fps : 87.75251478920642
# Estimated fps : 88.66879366440571
# Estimated fps : 81.07252559726965
# Estimated fps : 78.75689419565873
# Estimated fps : 82.3139545773829
# Estimated fps : 80.45654064445297
# Estimated fps : 84.408859543818
# Estimated fps : 81.83874947623346
# Estimated fps : 85.2418349780575
# Estimated fps : 79.82265059146725
# Estimated fps : 75.98731249729741
# Estimated fps : 77.30734893130474
# Estimated fps : 80.7615032965008
# Estimated fps : 82.97057018786018
# Estimated fps : 79.54091721532177
# Estimated fps : 82.70122324158964
# Estimated fps : 80.97728895543152
# Estimated fps : 77.4248243662865
# Estimated fps : 85.93568809582112
# Estimated fps : 85.89789386239156
# Estimated fps : 80.91205983889535
# Estimated fps : 80.86553191489399
# Estimated fps : 81.00527649769528
# Estimated fps : 85.31423509998103
# Estimated fps : 82.0067413109409
# Estimated fps : 75.25212980007613
# Estimated fps : 82.62542010387975
# Estimated fps : 85.28319142226363
# Estimated fps : 78.09732095254942
# Estimated fps : 80.3645819046323
# Estimated fps : 86.64947132329368
# Estimated fps : 78.60018333035326
# Estimated fps : 78.4283451568294
# Estimated fps : 73.96497022995594
# Estimated fps : 78.95854014598463
# Estimated fps : 78.81162571736013
# Estimated fps : 79.25580504080412
# Estimated fps : 82.5168172749663
# Estimated fps : 75.37313208841704
# Estimated fps : 81.4444006857267
# Estimated fps : 82.40656790586608
# Estimated fps : 81.66765006504303
# Estimated fps : 78.53346289594951
# Estimated fps : 85.76796779702322
# Estimated fps : 85.16336813546175
# Estimated fps : 81.74550654544836
# Estimated fps : 75.96925038355953
# Estimated fps : 81.46893611104805
# Estimated fps : 79.0117766041139
# Estimated fps : 78.34096176129643
# Estimated fps : 71.10900080906333
# Estimated fps : 76.36695195064725
# Estimated fps : 80.62444673775914
# Estimated fps : 84.97193889882439
# Estimated fps : 79.8679858239806
# Estimated fps : 89.38115577250632
# Estimated fps : 78.07477403451078
# Estimated fps : 81.35770156437985
# Estimated fps : 80.31501153679196
# Estimated fps : 89.10703604197118
# Estimated fps : 72.80845379613093
# Estimated fps : 82.39884216940719
# Estimated fps : 69.99480359169401
# Estimated fps : 73.29265953676452
# Estimated fps : 37.17095580460975
# Estimated fps : 61.749200829030364
# Estimated fps : 76.6851128803585
# Estimated fps : 78.58437087868973
# Estimated fps : 76.13541666666457
# Estimated fps : 82.36216469485791
# Estimated fps : 79.59854642606538
# Estimated fps : 80.72997611830615
# Estimated fps : 84.92678036525294
# Estimated fps : 85.78471036064583
# Estimated fps : 81.56533339520202
# Estimated fps : 75.69934542009436
# Estimated fps : 87.55582397330322
# Estimated fps : 76.23447393529237
# Estimated fps : 81.64489084997594
# Estimated fps : 76.05306537446562
# Estimated fps : 81.14737789677844
# Estimated fps : 82.21385809831126
# Estimated fps : 78.48262082821662
# Estimated fps : 80.57086217170092
# Estimated fps : 75.72380295948356
# Estimated fps : 74.60220689655196
# Estimated fps : 63.494536654083895
# Estimated fps : 63.64857427355836
# Estimated fps : 75.24568725653769
# Estimated fps : 84.33596411265157
# Estimated fps : 82.01822041806889
# Estimated fps : 86.17160154909536
# Estimated fps : 86.02821416336504
# Estimated fps : 88.12204536909482
# Estimated fps : 73.29265953676452
# Estimated fps : 81.4066827212508
# Estimated fps : 85.45940492974874
# Estimated fps : 82.78106383479803
# Estimated fps : 77.1953142154475
# Estimated fps : 76.04812996171269
# Estimated fps : 93.5804141822852
# Estimated fps : 83.09215315528378
# Estimated fps : 93.26017985516144
# Estimated fps : 78.75336574001498
# Estimated fps : 80.89716507892672
# Estimated fps : 81.64489084997594
# Estimated fps : 81.82160728000555
# Estimated fps : 84.48594155532015
# Estimated fps : 88.13309100025087
# Estimated fps : 89.34708244383664
# Estimated fps : 88.10658613603323
# Estimated fps : 83.3778963595399
# Estimated fps : 76.2576243980741
# Estimated fps : 80.91205983889535
# Estimated fps : 82.13510735228813
# Estimated fps : 89.42207808724596
# Estimated fps : 89.92528456324257
# Estimated fps : 83.99945045755305
# Estimated fps : 89.8930936613063
# Estimated fps : 75.38929513434657
# Estimated fps : 75.16364141705704
# Estimated fps : 85.78052410696661
# Estimated fps : 88.6866880250253
# Estimated fps : 81.859710806343
# Estimated fps : 82.46842599108498
# Estimated fps : 83.98339743436522
# Estimated fps : 89.39933884297514
# Estimated fps : 77.37881322357669
# Estimated fps : 75.94955605003297
# Estimated fps : 79.41873178665732
# Estimated fps : 78.02279233893398
# Estimated fps : 85.27078027602018
# Estimated fps : 82.0067413109409
# Estimated fps : 84.76297135692812
# Estimated fps : 78.3723973427262
# Estimated fps : 82.77911466917988
# Estimated fps : 78.96918169770282
# Estimated fps : 79.22187169028878
# Estimated fps : 0.9773585293816747
# Estimated fps : 85.57173108752745
# Estimated fps : 85.75750701305066
# Estimated fps : 85.05828413819941
# Estimated fps : 93.51320654342805
# Estimated fps : 86.23501275509746
# Estimated fps : 83.22197235110099
# Estimated fps : 87.90391058658616
# Estimated fps : 85.86852132285067
# Estimated fps : 75.8561472403272
# Estimated fps : 78.74278226980684
# Estimated fps : 81.56722581842276
# Estimated fps : 86.26463660008567
# Estimated fps : 84.75684081101396
# Estimated fps : 88.71578177046543
# Estimated fps : 83.66362057066335
# Estimated fps : 83.36801043395539
# Estimated fps : 81.01274310996646
# Estimated fps : 85.43033145411628
# Estimated fps : 72.39166872580454
# Estimated fps : 75.52696141617531
# Estimated fps : 76.34870892783631
# Estimated fps : 79.06330679620469
# Estimated fps : 85.7909905073336
# predict_gesture: Doing_other_things
# Estimated fps : 1.0037553433628095
# predict_gesture: Doing_other_things
# Estimated fps : 22.59648547720517
# predict_gesture: Doing_other_things
# Estimated fps : 21.53960065434358
# predict_gesture: Doing_other_things
# Estimated fps : 20.49343919230074
# predict_gesture: Doing_other_things
# Estimated fps : 21.634107468123787
# predict_gesture: Swiping_Up
# cleaning!
# Estimated fps : 20.879012477654808
# predict_gesture: Doing_other_things
# Estimated fps : 22.559655280838403
# predict_gesture: Doing_other_things
# Estimated fps : 22.36419442871757
# predict_gesture: Doing_other_things
# Estimated fps : 21.924857654241904
# predict_gesture: Swiping_Right
# cleaning!
# Estimated fps : 21.98587277366426
# predict_gesture: Doing_other_things
# Estimated fps : 21.299871557187103
# predict_gesture: Doing_other_things
# Estimated fps : 22.294700327860753
# predict_gesture: Doing_other_things
# Estimated fps : 22.05276033596994
# predict_gesture: Doing_other_things
# Estimated fps : 21.765366137539967
# predict_gesture: Doing_other_things
# Estimated fps : 23.026729806911355
# predict_gesture: Doing_other_things
# Estimated fps : 21.309942052177234
# predict_gesture: Doing_other_things
# Estimated fps : 22.558497224806782
# predict_gesture: Doing_other_things
# Estimated fps : 22.272242917236802
# predict_gesture: Doing_other_things
# Estimated fps : 21.28852139370972
# predict_gesture: Doing_other_things
# Estimated fps : 23.36618192452377
# predict_gesture: Doing_other_things
# Estimated fps : 21.788567851653553
# predict_gesture: Doing_other_things
# Estimated fps : 22.541140640528706
# predict_gesture: Doing_other_things
# Estimated fps : 21.81587961526544
# predict_gesture: Doing_other_things
# Estimated fps : 23.067674945047667
# predict_gesture: Doing_other_things
# Estimated fps : 21.632776253122827
# predict_gesture: Doing_other_things
# Estimated fps : 22.489374632174073
# predict_gesture: Doing_other_things
# Estimated fps : 21.373034063067788
# predict_gesture: Doing_other_things
# Estimated fps : 22.497145965316488
# predict_gesture: Doing_other_things
# Estimated fps : 21.38980895595019
# predict_gesture: Doing_other_things
# Estimated fps : 20.95754992548428
# predict_gesture: Doing_other_things
# Estimated fps : 22.2932865775939
# predict_gesture: Doing_other_things
# Estimated fps : 22.127852817885323
# predict_gesture: Doing_other_things
# Estimated fps : 22.552564053218465
# predict_gesture: Doing_other_things
# Estimated fps : 22.494554924242113
# predict_gesture: Doing_other_things
# Estimated fps : 21.555052115266975
# predict_gesture: Doing_other_things
# Estimated fps : 23.02205530853191
# predict_gesture: Doing_other_things
# Estimated fps : 21.580986347787942
# predict_gesture: Doing_other_things
# Estimated fps : 22.328967843147183
# predict_gesture: Doing_other_things
# Estimated fps : 22.5063633919313
# predict_gesture: Doing_other_things
# Estimated fps : 21.65356188176786
# predict_gesture: Doing_other_things
# Estimated fps : 23.064496870612352
# predict_gesture: Doing_other_things
# Estimated fps : 22.830390482437245
# predict_gesture: Doing_other_things
# Estimated fps : 21.081336011752853
# predict_gesture: Doing_other_things
# Estimated fps : 22.489950102354243
# predict_gesture: Doing_other_things
# Estimated fps : 22.86617712100318
# predict_gesture: Doing_other_things
# Estimated fps : 22.46149963582437
# predict_gesture: Doing_other_things
# Estimated fps : 23.00322576423787
# predict_gesture: Doing_other_things
# Estimated fps : 21.162170133872927
# predict_gesture: Doing_other_things
# Estimated fps : 23.088732875363267
# predict_gesture: Doing_other_things
# Estimated fps : 21.133547336086167
# predict_gesture: Doing_other_things
# Estimated fps : 21.99329996872048
# predict_gesture: Doing_other_things
# Estimated fps : 22.58371180245514
# predict_gesture: Doing_other_things
# Estimated fps : 21.83932487249657
# predict_gesture: Doing_other_things
# Estimated fps : 20.52358768688272
# predict_gesture: Doing_other_things
# Estimated fps : 20.942443900376116
# predict_gesture: Doing_other_things
# Estimated fps : 21.242471299093612
# predict_gesture: Doing_other_things
# Estimated fps : 21.790053365232946
# predict_gesture: Doing_other_things
# Estimated fps : 22.2343517774807
# predict_gesture: Doing_other_things
# Estimated fps : 22.81098494679443
# predict_gesture: Doing_other_things
# Estimated fps : 21.320022074252098
# predict_gesture: Doing_other_things
# Estimated fps : 20.762978230826047
# predict_gesture: Doing_other_things
# Estimated fps : 22.00679177725456
# predict_gesture: Doing_other_things
# Estimated fps : 21.553862754353933
# predict_gesture: Doing_other_things
# Estimated fps : 22.7373673351923
# predict_gesture: Doing_other_things
# Estimated fps : 22.841663797080685
# predict_gesture: Zooming_Out
# cleaning!
# Estimated fps : 22.538683950711775
# predict_gesture: Doing_other_things
# Estimated fps : 22.524965241515194
# predict_gesture: Doing_other_things
# Estimated fps : 21.991786614621404
# predict_gesture: Doing_other_things
# Estimated fps : 21.436631483954258
# predict_gesture: Doing_other_things
# Estimated fps : 22.261242607296406
# predict_gesture: Doing_other_things
# Estimated fps : 22.006103018959692
# predict_gesture: Doing_other_things
# Estimated fps : 22.824757996974114
# predict_gesture: Doing_other_things
# Estimated fps : 22.280853302235883
# predict_gesture: Doing_other_things
# Estimated fps : 22.078797470341357
# predict_gesture: Doing_other_things
# Estimated fps : 23.594192102225595
# predict_gesture: Doing_other_things
# Estimated fps : 22.81364940104662
# predict_gesture: Doing_other_things
# Estimated fps : 21.98821042361213
# predict_gesture: Doing_other_things
# Estimated fps : 22.59183883301787
# predict_gesture: Doing_other_things
# Estimated fps : 22.33464204260295
# predict_gesture: Doing_other_things
# Estimated fps : 21.633841212016815
# predict_gesture: Doing_other_things
# Estimated fps : 22.74236827635338
# predict_gesture: Doing_other_things
# Estimated fps : 22.075747395654147
# predict_gesture: Doing_other_things
# Estimated fps : 21.36563027967917
# predict_gesture: Doing_other_things
# Estimated fps : 23.092524352834747
# predict_gesture: Doing_other_things
# Estimated fps : 21.998529522188097
# predict_gesture: Doing_other_things
# Estimated fps : 22.499305622219765
# predict_gesture: Doing_other_things
# Estimated fps : 20.89651093675728
# predict_gesture: Doing_other_things
# Estimated fps : 22.94422581171529
# predict_gesture: Doing_other_things
# Estimated fps : 22.302762129517085
# predict_gesture: Doing_other_things
# Estimated fps : 22.283112866116305
# predict_gesture: Doing_other_things
# Estimated fps : 22.26110164822969
# predict_gesture: Doing_other_things
# Estimated fps : 22.061201822312643
# predict_gesture: Doing_other_things
# Estimated fps : 21.707577460266755
# predict_gesture: Doing_other_things
# Estimated fps : 22.23561742606262
# predict_gesture: Doing_other_things
# Estimated fps : 22.288763781374453
# predict_gesture: Doing_other_things
# Estimated fps : 21.563645842917044
# predict_gesture: Doing_other_things
# Estimated fps : 20.449095805632197
# predict_gesture: Doing_other_things
# Estimated fps : 22.1592343037952
# predict_gesture: Doing_other_things
# Estimated fps : 22.990890304354107
# predict_gesture: Doing_other_things
# Estimated fps : 22.30488462538926
# predict_gesture: Doing_other_things
# Estimated fps : 21.84570310072766
# predict_gesture: Doing_other_things
# Estimated fps : 22.063970929721282
# predict_gesture: Doing_other_things
# Estimated fps : 22.085455105131025
# predict_gesture: Doing_other_things
# Estimated fps : 22.50088963416147
# predict_gesture: Doing_other_things
# Estimated fps : 22.061617144112226
# predict_gesture: Doing_other_things
# Estimated fps : 22.07962945517357
# predict_gesture: Doing_other_things
# Estimated fps : 22.49441099501539
# predict_gesture: Doing_other_things
# Estimated fps : 21.366539239936824
# predict_gesture: Doing_other_things
# Estimated fps : 22.23997798541213
# predict_gesture: Doing_other_things
# Estimated fps : 22.76239405888056
# predict_gesture: Doing_other_things
# Estimated fps : 21.755399200484785
# predict_gesture: Doing_other_things
# Estimated fps : 20.627388740576297
# predict_gesture: Doing_other_things
# Estimated fps : 21.567349868410677
# predict_gesture: Doing_other_things
# Estimated fps : 22.744869571968394
# predict_gesture: Doing_other_things
# Estimated fps : 22.40567083896299
# predict_gesture: Doing_other_things
# Estimated fps : 22.499737603358636
# predict_gesture: Doing_other_things
# Estimated fps : 23.286012346332832
# predict_gesture: Doing_other_things
# Estimated fps : 22.313378650266415
# predict_gesture: Doing_other_things
# Estimated fps : 21.54197636014916
# predict_gesture: Doing_other_things
# Estimated fps : 22.348556026673645
# predict_gesture: Doing_other_things
# Estimated fps : 23.140099257543795
# predict_gesture: Doing_other_things
# Estimated fps : 21.797889424179704
# predict_gesture: Doing_other_things
# Estimated fps : 22.233508091801742
# predict_gesture: Doing_other_things
# Estimated fps : 22.280994511554216
# predict_gesture: Doing_other_things
# Estimated fps : 22.84210902475461
# predict_gesture: Doing_other_things
# Estimated fps : 21.92964432301618
# predict_gesture: Doing_other_things
# Estimated fps : 21.752572407947373
# predict_gesture: Doing_other_things
# Estimated fps : 21.55544859807407
# predict_gesture: Swiping_Down
# cleaning!
# Estimated fps : 22.5713872980813
# predict_gesture: Doing_other_things
# Estimated fps : 21.413259836764773
# predict_gesture: Doing_other_things
# Estimated fps : 22.26730553637829
# predict_gesture: Doing_other_things
# Estimated fps : 21.53960065434358
# predict_gesture: Doing_other_things
# Estimated fps : 22.509389506034836
# predict_gesture: Doing_other_things
# Estimated fps : 22.941830189049092
# predict_gesture: Doing_other_things
# Estimated fps : 20.039267657335348
# predict_gesture: Doing_other_things
# Estimated fps : 22.352392517897684
# predict_gesture: Doing_other_things
# Estimated fps : 22.24208854753245
# predict_gesture: Doing_other_things
# Estimated fps : 22.78319335355281
# predict_gesture: Doing_other_things
# Estimated fps : 22.261383568150023
# predict_gesture: Doing_other_things
# Estimated fps : 22.232242683328565
# predict_gesture: Doing_other_things
# Estimated fps : 21.051796717345635
# predict_gesture: Doing_other_things
# Estimated fps : 21.80153916753457
# predict_gesture: Doing_other_things
# Estimated fps : 22.825202565834672
# predict_gesture: Doing_other_things
# Estimated fps : 22.035068036377787
# predict_gesture: Zooming_In
# cleaning!
# Estimated fps : 21.36251443154899
# predict_gesture: Doing_other_things
# Estimated fps : 20.63707551876967
# predict_gesture: Doing_other_things
# Estimated fps : 22.311679327786482
# predict_gesture: Doing_other_things
# Estimated fps : 22.499593607803195
# predict_gesture: Doing_other_things
# Estimated fps : 21.789783256788738
# predict_gesture: Doing_other_things
# Estimated fps : 22.04349598083804
# predict_gesture: Doing_other_things
# Estimated fps : 23.328040397069763
# predict_gesture: Doing_other_things
# Estimated fps : 19.812946275099865
# predict_gesture: Doing_other_things
# Estimated fps : 22.847898564381847
# predict_gesture: Doing_other_things
# Estimated fps : 22.266600374949245
# predict_gesture: Doing_other_things
# Estimated fps : 22.247014750643785
# predict_gesture: Doing_other_things
# Estimated fps : 23.295424576747923
# predict_gesture: Doing_other_things
# Estimated fps : 22.063417052628708
# predict_gesture: Doing_other_things
# Estimated fps : 22.497433895615163
# predict_gesture: Doing_other_things
# Estimated fps : 22.257719166070714
# predict_gesture: Doing_other_things
# Estimated fps : 21.766174667838605
# predict_gesture: Doing_other_things
# Estimated fps : 21.708113615313422
# predict_gesture: Doing_other_things
# Estimated fps : 21.518374566955412
# predict_gesture: Doing_other_things
# Estimated fps : 21.290197360851842
# predict_gesture: Doing_other_things
# Estimated fps : 22.490957246038562
# predict_gesture: Doing_other_things
# Estimated fps : 22.233508091801742
# predict_gesture: Doing_other_things
# Estimated fps : 22.030097190803495
# predict_gesture: Doing_other_things
# Estimated fps : 22.51688624441999
# predict_gesture: Doing_other_things
# Estimated fps : 22.300640037552853
# predict_gesture: Doing_other_things
# Estimated fps : 22.096976744186
# predict_gesture: Doing_other_things
# Estimated fps : 22.749873814176812
# predict_gesture: Doing_other_things
# Estimated fps : 21.112606444949005
# predict_gesture: Doing_other_things
# Estimated fps : 23.348336023059073
# predict_gesture: Doing_other_things
# Estimated fps : 20.053555945970896
# predict_gesture: Zooming_Out
# cleaning!
# Estimated fps : 21.52812545926598
# predict_gesture: Doing_other_things
# Estimated fps : 23.069794147947967
# predict_gesture: Doing_other_things
# Estimated fps : 21.5488424549645
# predict_gesture: Doing_other_things
# Estimated fps : 22.99961401580618
# predict_gesture: Doing_other_things
# Estimated fps : 19.824565657477432
# predict_gesture: Doing_other_things
# Estimated fps : 21.177977639092823
# predict_gesture: Doing_other_things
# Estimated fps : 22.774042883980027
# predict_gesture: Doing_other_things
# Estimated fps : 20.269533682341475
# predict_gesture: Doing_other_things
# Estimated fps : 22.28749207556727
# predict_gesture: Doing_other_things
# Estimated fps : 22.048334598089603
# predict_gesture: Doing_other_things
# Estimated fps : 21.83688313301674
# predict_gesture: Doing_other_things
# Estimated fps : 22.57544564882354
# predict_gesture: Doing_other_things
# Estimated fps : 21.34111755243246
# predict_gesture: Doing_other_things
# Estimated fps : 21.08727911803114
# predict_gesture: Doing_other_things
# Estimated fps : 20.70782162063423
# predict_gesture: Doing_other_things
# Estimated fps : 22.511551514375313
# predict_gesture: Doing_other_things
# Estimated fps : 22.81068893473985
# predict_gesture: Doing_other_things
# Estimated fps : 22.678697449989205
# predict_gesture: Doing_other_things
# Estimated fps : 23.287863331655128
# predict_gesture: Doing_other_things
# Estimated fps : 22.326557181323984
# predict_gesture: Doing_other_things
# Estimated fps : 20.44493358766223
# predict_gesture: Doing_other_things
# Estimated fps : 21.834170729434675
# predict_gesture: Doing_other_things
# Estimated fps : 21.317695069005044
# predict_gesture: Doing_other_things
# Estimated fps : 22.276617854857268
# predict_gesture: Doing_other_things
# Estimated fps : 21.828883480074435
# predict_gesture: Doing_other_things
# Estimated fps : 21.669444461565313
# predict_gesture: Doing_other_things
# Estimated fps : 22.01974846233828
# predict_gesture: Doing_other_things
# Estimated fps : 22.01133866352805
# predict_gesture: Doing_other_things
# Estimated fps : 22.516309394954817
# predict_gesture: Doing_other_things
# Estimated fps : 22.491532797215715
# predict_gesture: Doing_other_things
# Estimated fps : 21.572908293192267
# predict_gesture: Doing_other_things
# Estimated fps : 22.043357765836795
# predict_gesture: Doing_other_things
# Estimated fps : 20.96829969462747
# predict_gesture: Doing_other_things
# Estimated fps : 22.80906100575477
# predict_gesture: Doing_other_things
# Estimated fps : 22.37657849177612
# predict_gesture: Doing_other_things
# Estimated fps : 22.009960620801376
# predict_gesture: Doing_other_things
# Estimated fps : 22.51169566303206
# predict_gesture: Doing_other_things
# Estimated fps : 20.257970647044846
# predict_gesture: Doing_other_things
# Estimated fps : 20.561638788162163
# predict_gesture: Doing_other_things
# Estimated fps : 22.764604944506935
# predict_gesture: Doing_other_things
# Estimated fps : 20.84842967953131
# predict_gesture: Doing_other_things
# Estimated fps : 21.79680825340475
# predict_gesture: Zooming_In
# cleaning!
# Estimated fps : 20.86624842714977
# predict_gesture: Doing_other_things
# Estimated fps : 21.754322240510913
# predict_gesture: Doing_other_things
# Estimated fps : 22.13690944696043
# predict_gesture: Doing_other_things
# Estimated fps : 21.68829350146133
# predict_gesture: Doing_other_things
# Estimated fps : 21.136723822807575
# predict_gesture: Doing_other_things
# Estimated fps : 22.00513882977436
# predict_gesture: Doing_other_things
# Estimated fps : 22.255182978940095
# predict_gesture: Doing_other_things
# Estimated fps : 22.050270639813014
# predict_gesture: Doing_other_things
# Estimated fps : 21.367837888761354
# predict_gesture: Doing_other_things
# Estimated fps : 21.51771604144789
# predict_gesture: Doing_other_things
# Estimated fps : 21.826173063312133
# predict_gesture: Doing_other_things
# Estimated fps : 21.299484420533823
# predict_gesture: Doing_other_things
# Estimated fps : 21.844481449493117
# predict_gesture: Doing_other_things
# Estimated fps : 21.554127045436637
# predict_gesture: Doing_other_things
# Estimated fps : 22.31932831793852
# predict_gesture: Doing_other_things
# Estimated fps : 21.098289033852883
# predict_gesture: Doing_other_things
# Estimated fps : 22.835580757889243
# predict_gesture: Doing_other_things
# Estimated fps : 22.352818876010325
# predict_gesture: Doing_other_things
# Estimated fps : 21.692308166943338
# predict_gesture: Doing_other_things
# Estimated fps : 22.79442009440374
# predict_gesture: Doing_other_things
# Estimated fps : 21.33464210941511
# predict_gesture: Doing_other_things
# Estimated fps : 22.25095728453994
# predict_gesture: Doing_other_things
# Estimated fps : 20.079440960442003
# predict_gesture: Doing_other_things
# Estimated fps : 22.067571808778524
# predict_gesture: Doing_other_things
# Estimated fps : 21.896726978294332
# predict_gesture: Doing_other_things
# Estimated fps : 20.072447715347547
# predict_gesture: Doing_other_things
# Estimated fps : 20.255636281927206
# predict_gesture: Doing_other_things
# Estimated fps : 21.923490418372378
# predict_gesture: Doing_other_things
# Estimated fps : 22.06660222572395
# predict_gesture: Doing_other_things
# Estimated fps : 22.071866700987137
# predict_gesture: Doing_other_things
# Estimated fps : 22.05677269590198
# predict_gesture: Doing_other_things
# Estimated fps : 22.022645126129266
# predict_gesture: Doing_other_things
# Estimated fps : 21.82590205865611
# predict_gesture: Doing_other_things
# Estimated fps : 22.769765348219554
# predict_gesture: Doing_other_things
# Estimated fps : 22.02085186345005
# predict_gesture: Doing_other_things
# Estimated fps : 21.302840072471067
# predict_gesture: Doing_other_things
# Estimated fps : 22.795602500259417
# predict_gesture: Doing_other_things
# Estimated fps : 22.500745623859988
# predict_gesture: Doing_other_things
# Estimated fps : 21.66210087865239
# predict_gesture: Doing_other_things
# Estimated fps : 22.31649474719889
# predict_gesture: Doing_other_things
# Estimated fps : 22.29257976969571
# predict_gesture: Doing_other_things
# Estimated fps : 22.769175469389005
# predict_gesture: Doing_other_things
# Estimated fps : 20.868725662456097
# predict_gesture: Doing_other_things
# Estimated fps : 20.722957400280105
# predict_gesture: Doing_other_things
# Estimated fps : 20.925242100126155
# predict_gesture: Doing_other_things
# Estimated fps : 22.284807839805865
# predict_gesture: Doing_other_things
# Estimated fps : 22.604767048596923
# predict_gesture: Doing_other_things
# Estimated fps : 22.74854894754123
# predict_gesture: Doing_other_things
# Estimated fps : 20.19675530967674
# predict_gesture: Doing_other_things
# Estimated fps : 22.53839496358563
# predict_gesture: Doing_other_things
# Estimated fps : 22.520059444881124
# predict_gesture: Doing_other_things
# Estimated fps : 22.747518602393104
# predict_gesture: Doing_other_things
# Estimated fps : 22.264203160127433
# predict_gesture: Doing_other_things
# Estimated fps : 22.25870561718018
# predict_gesture: Doing_other_things
# Estimated fps : 23.11013311421559
# predict_gesture: Doing_other_things
# Estimated fps : 22.30729060913733
# predict_gesture: Doing_other_things
# Estimated fps : 22.712542315942276
# predict_gesture: Doing_other_things
# Estimated fps : 21.799646555465586
# predict_gesture: Doing_other_things
# Estimated fps : 22.812613150432053
# predict_gesture: Doing_other_things
# Estimated fps : 21.82495359535197
# predict_gesture: Doing_other_things
# Estimated fps : 22.80358694947114
# predict_gesture: Doing_other_things
# Estimated fps : 21.540788441742162
# predict_gesture: Doing_other_things
# Estimated fps : 21.56814375371994
# predict_gesture: Doing_other_things
# Estimated fps : 21.608178292430676
# predict_gesture: Doing_other_things
# Estimated fps : 19.674678769699586
# predict_gesture: Doing_other_things
# Estimated fps : 22.35779425606114
# predict_gesture: Doing_other_things
# Estimated fps : 22.320745373161877
# predict_gesture: Doing_other_things
# Estimated fps : 22.003210704853302
# predict_gesture: Doing_other_things
# Estimated fps : 21.31782433374826
# predict_gesture: Doing_other_things
# Estimated fps : 21.143969784267494
# predict_gesture: Doing_other_things
# Estimated fps : 22.326415393895783
# predict_gesture: Doing_other_things
# Estimated fps : 22.23603934094401
# predict_gesture: Doing_other_things
# Estimated fps : 21.60897518639397
# predict_gesture: Doing_other_things
# Estimated fps : 21.590926677680486
# predict_gesture: Doing_other_things
# Estimated fps : 22.332513879890108
# predict_gesture: Doing_other_things
# Estimated fps : 21.345393498560387
# predict_gesture: Doing_other_things
# Estimated fps : 21.14638620888683
# predict_gesture: Doing_other_things
# Estimated fps : 20.452307817608954
# predict_gesture: Doing_other_things
# Estimated fps : 21.367318410288814
# predict_gesture: Doing_other_things
# Estimated fps : 21.132022961560658
# predict_gesture: Doing_other_things
# Estimated fps : 21.148803185889868
# predict_gesture: Doing_other_things
# Estimated fps : 22.541574229621155
# predict_gesture: Doing_other_things
# Estimated fps : 20.688202478609977
# predict_gesture: Doing_other_things
# Estimated fps : 21.35602599927201
# predict_gesture: Doing_other_things
# Estimated fps : 20.923996690850704
# predict_gesture: Doing_other_things
# Estimated fps : 21.84977625854561
# predict_gesture: Doing_other_things
# Estimated fps : 21.35343172983512
# predict_gesture: Doing_other_things
# Estimated fps : 19.088109936528884
# predict_gesture: Doing_other_things
# Estimated fps : 21.840003230375736
# predict_gesture: Doing_other_things
# Estimated fps : 21.36809763747065
# predict_gesture: Doing_other_things
# Estimated fps : 22.23575806257856
# predict_gesture: Doing_other_things
# Estimated fps : 21.565762273109993
# predict_gesture: Doing_other_things
# Estimated fps : 21.505211710442918
# predict_gesture: Doing_other_things
# Estimated fps : 21.314722412528408
# predict_gesture: Doing_other_things
# Estimated fps : 21.284010485721147
# predict_gesture: Doing_other_things
# Estimated fps : 21.798565210382083
# predict_gesture: Doing_other_things
# Estimated fps : 20.71172551122045
# predict_gesture: Doing_other_things
# Estimated fps : 21.629715080259004
# predict_gesture: Doing_other_things
# Estimated fps : 21.57092281261421
# predict_gesture: Doing_other_things
# Estimated fps : 20.68418575370464
# predict_gesture: Doing_other_things
# Estimated fps : 21.57833713878828
# predict_gesture: Doing_other_things
# Estimated fps : 20.904711786601435
# predict_gesture: Doing_other_things
# Estimated fps : 21.82034794590239
# predict_gesture: Doing_other_things
# Estimated fps : 21.130371803964138
# predict_gesture: Doing_other_things
# Estimated fps : 22.309980264117826
# predict_gesture: Doing_other_things
# Estimated fps : 21.59702794517893
# predict_gesture: Doing_other_things
# Estimated fps : 20.489497732862063
# predict_gesture: Doing_other_things
# Estimated fps : 21.347337676927165
# predict_gesture: Doing_other_things
# Estimated fps : 22.06535574412522
# predict_gesture: Doing_other_things
# Estimated fps : 22.825498954695448
# predict_gesture: Doing_other_things
# Estimated fps : 20.901356115600144
# predict_gesture: Doing_other_things
# Estimated fps : 21.378882780764624
# predict_gesture: Doing_other_things
# Estimated fps : 21.595170672678503
# predict_gesture: Doing_other_things
# Estimated fps : 21.577807375036674
# predict_gesture: Doing_other_things
# Estimated fps : 22.089618166166876
# predict_gesture: Doing_other_things
# Estimated fps : 21.398010919249856
# predict_gesture: Doing_other_things
# Estimated fps : 22.123257672533597
# predict_gesture: Doing_other_things
# Estimated fps : 21.328299986654255
# predict_gesture: Doing_other_things
# Estimated fps : 20.479233171004328
# predict_gesture: Doing_other_things
# Estimated fps : 22.29413480623787
# predict_gesture: Zooming_In
# cleaning!
# Estimated fps : 20.27152058214749
# predict_gesture: Doing_other_things
# Estimated fps : 20.674454709580473
# predict_gesture: Doing_other_things
# Estimated fps : 21.364461730119586
# predict_gesture: Doing_other_things
# Estimated fps : 21.82888348007528
# predict_gesture: Doing_other_things
# Estimated fps : 22.32343827387862
# predict_gesture: Doing_other_things
# Estimated fps : 20.677859533346673
# predict_gesture: Doing_other_things
# Estimated fps : 20.41750538658624
# predict_gesture: Doing_other_things
# Estimated fps : 21.40283087787588
# predict_gesture: Doing_other_things
# Estimated fps : 21.64769522542716
# predict_gesture: Doing_other_things
# Estimated fps : 20.042352203408715
# predict_gesture: Doing_other_things
# Estimated fps : 22.027474593049885
# predict_gesture: Doing_other_things
# Estimated fps : 20.912048300270808
# predict_gesture: Doing_other_things
# Estimated fps : 22.098782427225924
# predict_gesture: Doing_other_things
# Estimated fps : 21.346689578121246
# predict_gesture: Doing_other_things
# Estimated fps : 21.328946969283685
# predict_gesture: Doing_other_things
# Estimated fps : 21.08867054172747
# predict_gesture: Doing_other_things
# Estimated fps : 21.566952947671776
# predict_gesture: Doing_other_things
# Estimated fps : 22.3085645753893
# predict_gesture: Doing_other_things
# Estimated fps : 21.099175388900836
# predict_gesture: Doing_other_things
# Estimated fps : 19.52086109630329
# predict_gesture: Doing_other_things
# Estimated fps : 21.82630856816389
# predict_gesture: Doing_other_things
# Estimated fps : 22.07422267430176
# predict_gesture: Doing_other_things
# Estimated fps : 19.86141304347827
# predict_gesture: Doing_other_things
# Estimated fps : 21.823056916019926
# predict_gesture: Doing_other_things
# Estimated fps : 22.067294776353638
# predict_gesture: Doing_other_things
# Estimated fps : 21.604725764326247
# predict_gesture: Doing_other_things
# Estimated fps : 21.16331665854017
# predict_gesture: Doing_other_things
# Estimated fps : 21.584696333405883
# predict_gesture: Doing_other_things
# Estimated fps : 21.62173348831782
# predict_gesture: Doing_other_things
# Estimated fps : 21.354728785762656
# predict_gesture: Doing_other_things
# Estimated fps : 20.08953816615062
# predict_gesture: Doing_other_things
# Estimated fps : 22.026784539525575
# predict_gesture: Doing_other_things
# Estimated fps : 21.63783574189269
# predict_gesture: Doing_other_things
# Estimated fps : 21.13545311353922
# predict_gesture: Doing_other_things
# Estimated fps : 21.512449288043545
# predict_gesture: Doing_other_things
# Estimated fps : 21.749342687278993
# predict_gesture: Doing_other_things
# Estimated fps : 21.3662795291134
# predict_gesture: Doing_other_things
# Estimated fps : 21.283366226344693
# predict_gesture: Doing_other_things
# Estimated fps : 22.284807839805865
# predict_gesture: Doing_other_things
# Estimated fps : 20.06797917641799
# predict_gesture: Doing_other_things
# Estimated fps : 22.26533119691859
# predict_gesture: Doing_other_things
# Estimated fps : 22.299225533912484
# predict_gesture: Doing_other_things
# Estimated fps : 21.516135744667704
# predict_gesture: Doing_other_things
# Estimated fps : 19.449476368826353
# predict_gesture: Doing_other_things
# Estimated fps : 21.330370469245093
# predict_gesture: Doing_other_things
# Estimated fps : 21.615485354517
# predict_gesture: Zooming_In
# cleaning!
# Estimated fps : 20.917771867507106
# predict_gesture: Doing_other_things
# Estimated fps : 21.552805654836597
# predict_gesture: Doing_other_things
# Estimated fps : 20.704163059544964
# predict_gesture: Doing_other_things
# Estimated fps : 21.356544928804766
# predict_gesture: Doing_other_things
# Estimated fps : 21.557034675169312
# predict_gesture: Doing_other_things
# Estimated fps : 21.59862014732331
# predict_gesture: Doing_other_things
# Estimated fps : 22.3232965260615
# predict_gesture: Doing_other_things
# Estimated fps : 19.44452802221159
# predict_gesture: Doing_other_things
# Estimated fps : 22.55401088044432
# predict_gesture: Doing_other_things
# Estimated fps : 21.75916940025982
# predict_gesture: Doing_other_things
# Estimated fps : 21.205825582376818
# predict_gesture: Doing_other_things
# Estimated fps : 21.546993460447496
# predict_gesture: Doing_other_things
# Estimated fps : 21.553466329882983
# predict_gesture: Doing_other_things
# Estimated fps : 22.044739993854467
# predict_gesture: Doing_other_things
# Estimated fps : 20.678954179165533
# predict_gesture: Doing_other_things
# Estimated fps : 21.35252388443181
# predict_gesture: Doing_other_things
# Estimated fps : 21.60937365541851
# predict_gesture: Doing_other_things
# Estimated fps : 20.451950877560595
# predict_gesture: Doing_other_things
# Estimated fps : 20.30981513575913
# predict_gesture: Doing_other_things
# Estimated fps : 20.922004344332496
# predict_gesture: Doing_other_things
# Estimated fps : 22.263639184593384
# predict_gesture: Doing_other_things
# Estimated fps : 21.56602685609456
# predict_gesture: Doing_other_things
# Estimated fps : 21.612561936729918
# predict_gesture: Doing_other_things
# Estimated fps : 21.81615037108835
# predict_gesture: Doing_other_things
# Estimated fps : 20.142715542925952
# predict_gesture: Doing_other_things
# Estimated fps : 21.60552240365172
# predict_gesture: Doing_other_things
# Estimated fps : 21.1872947188898
# predict_gesture: Doing_other_things
# Estimated fps : 21.841767158097028
# predict_gesture: Doing_other_things
# Estimated fps : 21.383564060143247
# predict_gesture: Doing_other_things
# Estimated fps : 22.046122395228995
# predict_gesture: Doing_other_things
# Estimated fps : 20.657811545151972
# predict_gesture: Doing_other_things
# Estimated fps : 20.917896327676765
# predict_gesture: Doing_other_things
# Estimated fps : 21.56113312154298
# predict_gesture: Doing_other_things
# Estimated fps : 21.579794123243197
# predict_gesture: Doing_other_things
# Estimated fps : 21.569202358383727
# predict_gesture: Doing_other_things
# Estimated fps : 21.540128543681956
# predict_gesture: Doing_other_things
# Estimated fps : 22.034791819440947
# predict_gesture: Doing_other_things
# Estimated fps : 21.77911932698045
# predict_gesture: Doing_other_things
# Estimated fps : 21.14015550116987
# predict_gesture: Doing_other_things
# Estimated fps : 21.104875164336732
# predict_gesture: Doing_other_things
# Estimated fps : 21.779524095675733
# predict_gesture: Doing_other_things
# Estimated fps : 21.83430633361064
# predict_gesture: Zooming_In
# cleaning!
# Estimated fps : 20.113905003834166
# predict_gesture: Doing_other_things
# Estimated fps : 22.31422840857953
# predict_gesture: Doing_other_things
# Estimated fps : 21.376152980877563
# predict_gesture: Doing_other_things
# Estimated fps : 20.35909567352529
# predict_gesture: Doing_other_things
# Estimated fps : 21.795862316953066
# predict_gesture: Doing_other_things
# Estimated fps : 21.606717472803957
# predict_gesture: Doing_other_things
# Estimated fps : 22.051930374784646
# predict_gesture: Doing_other_things
# Estimated fps : 20.25808737942346
# predict_gesture: Doing_other_things
# Estimated fps : 22.075331541670042
# predict_gesture: Doing_other_things
# Estimated fps : 19.47716897507016
# predict_gesture: Doing_other_things
# Estimated fps : 21.173768497383314
# predict_gesture: Doing_other_things
# Estimated fps : 22.55068345531392
# predict_gesture: Doing_other_things
# Estimated fps : 20.842743991369396
# predict_gesture: Doing_other_things
# Estimated fps : 21.811819084254495
# predict_gesture: Doing_other_things
# Estimated fps : 21.136469668731355
# predict_gesture: Doing_other_things
# Estimated fps : 22.519482432822937
# predict_gesture: Zooming_In
# cleaning!
# Estimated fps : 21.537225472478386
# predict_gesture: Doing_other_things
# Estimated fps : 21.365500434524865
# predict_gesture: Doing_other_things
# Estimated fps : 21.566820644005936
# predict_gesture: Doing_other_things
# Estimated fps : 20.881492744756983
# predict_gesture: Doing_other_things
# Estimated fps : 21.90696036889354
# predict_gesture: Doing_other_things
# Estimated fps : 21.6071158585677
# predict_gesture: Doing_other_things
# Estimated fps : 22.339183478951604
# predict_gesture: Doing_other_things
# Estimated fps : 21.809248196328493
# predict_gesture: Doing_other_things
# Estimated fps : 20.92698592219919
# predict_gesture: Doing_other_things
# Estimated fps : 20.65647639472467
# predict_gesture: Doing_other_things
# Estimated fps : 21.184613623216798
# predict_gesture: Doing_other_things
# Estimated fps : 22.078104197543492
# predict_gesture: Doing_other_things
# Estimated fps : 22.322587813983947
# predict_gesture: Doing_other_things
# Estimated fps : 20.302308793975044
# predict_gesture: Doing_other_things
# Estimated fps : 21.350189779249128
# predict_gesture: Doing_other_things
# Estimated fps : 20.740072798494758
# predict_gesture: Doing_other_things
# Estimated fps : 22.03921212159199
# predict_gesture: Doing_other_things
# Estimated fps : 21.758630720289236
# predict_gesture: Doing_other_things
# Estimated fps : 22.291448970274182
# predict_gesture: Doing_other_things
# Estimated fps : 22.279723692131952
# predict_gesture: Doing_other_things
# Estimated fps : 21.376023007795553
# predict_gesture: Doing_other_things
# Estimated fps : 21.607381457239132
# predict_gesture: Doing_other_things
# Estimated fps : 21.62678781242567
# predict_gesture: Doing_other_things
# Estimated fps : 22.27139635359329
# predict_gesture: Doing_other_things
# Estimated fps : 22.35210828819295
# predict_gesture: Doing_other_things
# Estimated fps : 19.880731299056404
# predict_gesture: Doing_other_things
# Estimated fps : 22.320320237702823
# predict_gesture: Doing_other_things
# Estimated fps : 20.885462398042147
# predict_gesture: Doing_other_things
# Estimated fps : 22.2769001679172
# predict_gesture: Doing_other_things
# Estimated fps : 19.136840672798517
# predict_gesture: Doing_other_things
# Estimated fps : 21.852900041645885
# predict_gesture: Doing_other_things
# Estimated fps : 20.297971720717495
# predict_gesture: Doing_other_things
# Estimated fps : 21.80816589850331
# predict_gesture: Doing_other_things
# Estimated fps : 20.918394183167997
# predict_gesture: Doing_other_things
# Estimated fps : 22.102533635107555
# predict_gesture: Doing_other_things
# Estimated fps : 21.15860396254045
# predict_gesture: Doing_other_things
# Estimated fps : 21.413129412052037
# predict_gesture: Doing_other_things
# Estimated fps : 22.30799835020103
# predict_gesture: Doing_other_things
# Estimated fps : 21.65636299795954
# predict_gesture: Doing_other_things
# Estimated fps : 20.05378472420375
# predict_gesture: Doing_other_things
# Estimated fps : 22.092810909320104
# predict_gesture: Doing_other_things
# Estimated fps : 21.168286368015718
# predict_gesture: Doing_other_things
# Estimated fps : 22.06452483462347
# predict_gesture: Doing_other_things
# Estimated fps : 21.365889974716826
# predict_gesture: Doing_other_things
# Estimated fps : 21.791268936107173
# predict_gesture: Doing_other_things
# Estimated fps : 22.03838317985606
# predict_gesture: Doing_other_things
# Estimated fps : 20.6154139350522
# predict_gesture: Doing_other_things
# Estimated fps : 22.299932763302763
# predict_gesture: Doing_other_things
# Estimated fps : 21.56047197640227
# predict_gesture: Doing_other_things
# Estimated fps : 22.075331541670042
# predict_gesture: Doing_other_things
# Estimated fps : 22.830093966531738
# predict_gesture: Doing_other_things
# Estimated fps : 21.205825582376818
# predict_gesture: Doing_other_things
# Estimated fps : 22.255182978938336
# predict_gesture: Doing_other_things
# Estimated fps : 21.781278267226604
# predict_gesture: Doing_other_things
# Estimated fps : 23.352988847041033
# predict_gesture: Doing_other_things
# Estimated fps : 22.539261947197875
# predict_gesture: Doing_other_things
# Estimated fps : 22.276476701010576
# predict_gesture: Doing_other_things
# Estimated fps : 23.312880465776313
# predict_gesture: Doing_other_things
# Estimated fps : 22.836174082494612
# predict_gesture: Doing_other_things
# Estimated fps : 20.018158317295338
# predict_gesture: Doing_other_things
# Estimated fps : 23.011205728535312
# predict_gesture: Doing_other_things
# Estimated fps : 20.28813226765087
# predict_gesture: Doing_other_things
# Estimated fps : 22.25194313636156
# predict_gesture: Doing_other_things
# Estimated fps : 21.137486321713435
# predict_gesture: Doing_other_things
# Estimated fps : 20.464808573307703
# predict_gesture: Doing_other_things
# Estimated fps : 21.0839910281621
# predict_gesture: Doing_other_things
# Estimated fps : 21.937854905337307
# predict_gesture: Doing_other_things
# Estimated fps : 21.53339989219942
# predict_gesture: Doing_other_things
# Estimated fps : 21.16611979746768
# predict_gesture: Doing_other_things
# Estimated fps : 20.43566388039509
# predict_gesture: Doing_other_things
# Estimated fps : 20.506349123022215
# predict_gesture: Doing_other_things
# Estimated fps : 23.017684108526332
# predict_gesture: Doing_other_things
# Estimated fps : 22.898645215919327
# predict_gesture: Doing_other_things
# Estimated fps : 22.295407270236183
# predict_gesture: Doing_other_things
# Estimated fps : 23.269982790574513
# predict_gesture: Doing_other_things
# Estimated fps : 22.75650046281681
# predict_gesture: Doing_other_things
# Estimated fps : 22.033687020939546
# predict_gesture: Doing_other_things
# Estimated fps : 23.057689659017562
# predict_gesture: Doing_other_things
# Estimated fps : 21.787082540606953
# predict_gesture: Doing_other_things
# Estimated fps : 21.783707586685278
# predict_gesture: Doing_other_things
# Estimated fps : 23.082062898037016
# predict_gesture: Doing_other_things
# Estimated fps : 22.834097581252923
# predict_gesture: Doing_other_things
# Estimated fps : 21.8191291287553
# predict_gesture: Doing_other_things
# Estimated fps : 22.084761414178097
# predict_gesture: Doing_other_things
# Estimated fps : 22.12924566306774
# predict_gesture: Doing_other_things
# Estimated fps : 23.60242897040655
# predict_gesture: Doing_other_things
# Estimated fps : 21.3133010003034
# predict_gesture: Doing_other_things
# Estimated fps : 22.04197571114251
# predict_gesture: Doing_other_things
# Estimated fps : 22.798263361996252
# predict_gesture: Doing_other_things
# Estimated fps : 19.33417108917452
# predict_gesture: Doing_other_things
# Estimated fps : 21.157585277195636
# predict_gesture: Doing_other_things
# Estimated fps : 23.370841864546637
# predict_gesture: Doing_other_things
# Estimated fps : 21.669043774115966
# predict_gesture: Doing_other_things
# Estimated fps : 22.281700584987938
# predict_gesture: Doing_other_things
# Estimated fps : 21.604858533467176
# predict_gesture: Doing_other_things
# Estimated fps : 20.651744069926643
# predict_gesture: Doing_other_things
# Estimated fps : 23.350817298432336
# predict_gesture: Swiping_Down
# cleaning!
# Estimated fps : 22.638245672779316
# predict_gesture: Doing_other_things
# ...
# Estimated fps : 19.81942463483001
# predict_gesture: Doing_other_things
# Estimated fps : 22.768438163826904
# predict_gesture: Doing_other_things
# Estimated fps : 22.88478287756469
# predict_gesture: Doing_other_things
# Estimated fps : 22.928364127281135
# predict_gesture: Doing_other_things
# Estimated fps : 23.62447501226568
# predict_gesture: Doing_other_things
# Estimated fps : 20.89315789786586
# predict_gesture: Doing_other_things
# Estimated fps : 22.32513938809089
# predict_gesture: Doing_other_things
# Estimated fps : 22.873615792006703
# predict_gesture: Doing_other_things
# Estimated fps : 20.227316663404427
# predict_gesture: Doing_other_things
# Estimated fps : 23.34446008579086
# predict_gesture: Doing_other_things
# Estimated fps : 22.509966000986143
# predict_gesture: Doing_other_things
# Estimated fps : 20.697824615113277
# predict_gesture: Doing_other_things
# Estimated fps : 22.50103364630637
# predict_gesture: Doing_other_things
# Estimated fps : 22.516309394953918
# predict_gesture: Doing_other_things
# Estimated fps : 22.076995051621278
# predict_gesture: Doing_other_things
# Estimated fps : 21.52667544316442
# predict_gesture: Doing_other_things
# Estimated fps : 22.836025748453245
# predict_gesture: Doing_other_things
# Estimated fps : 23.014067818801315
# predict_gesture: Doing_other_things
# Estimated fps : 23.086458586428897
# predict_gesture: Doing_other_things
# Estimated fps : 21.137232149298395
# predict_gesture: Doing_other_things
# Estimated fps : 23.00548368309865
# predict_gesture: Doing_other_things
# Estimated fps : 21.37004595409339
# predict_gesture: Doing_other_things
# Estimated fps : 21.831458999599462
# predict_gesture: Doing_other_things
# Estimated fps : 23.114995430429683
# predict_gesture: Doing_other_things
# Estimated fps : 21.822108699968837
# predict_gesture: Doing_other_things
# Estimated fps : 23.84269350496276
# predict_gesture: Doing_other_things
# Estimated fps : 22.82831503282594
# predict_gesture: Doing_other_things
# Estimated fps : 22.509966000986143
# predict_gesture: Doing_other_things
# Estimated fps : 22.510686661200328
# predict_gesture: Doing_other_things
# Estimated fps : 22.269562353118378
# predict_gesture: Doing_other_things
# Estimated fps : 22.78171697403951
# predict_gesture: Doing_other_things
# Estimated fps : 23.278765486053718
# predict_gesture: Doing_other_things
# Estimated fps : 22.994649713191553
# predict_gesture: Doing_other_things
# Estimated fps : 20.6376812444953
# predict_gesture: Doing_other_things
# Estimated fps : 22.83454251401189
# predict_gesture: Doing_other_things
# Estimated fps : 23.34554521850537
# predict_gesture: Doing_other_things
# Estimated fps : 21.930191503961822
# predict_gesture: Doing_other_things
# Estimated fps : 22.510110129337544
# predict_gesture: Doing_other_things
# Estimated fps : 21.564042641935465
# predict_gesture: Doing_other_things
# Estimated fps : 20.903841694362857
# predict_gesture: Doing_other_things
# Estimated fps : 23.610195899344344
# predict_gesture: Zooming_In
# cleaning!
# Estimated fps : 20.267079814373275
# predict_gesture: Doing_other_things
# Estimated fps : 22.606947418510757
# predict_gesture: Doing_other_things
# Estimated fps : 23.0069892086086
# predict_gesture: Doing_other_things
# Estimated fps : 23.121532390663095
# predict_gesture: Doing_other_things
# Estimated fps : 21.819264546158262
# predict_gesture: Doing_other_things
# Estimated fps : 22.49297180404075
# predict_gesture: Doing_other_things
# Estimated fps : 23.587543442960673
# predict_gesture: Doing_other_things
# Estimated fps : 22.771387672615273
# predict_gesture: Doing_other_things
# Estimated fps : 22.31493658995011
# predict_gesture: Doing_other_things
# Estimated fps : 20.678954179165533
# predict_gesture: Doing_other_things
# Estimated fps : 21.12757812500153
# predict_gesture: Zooming_In
# cleaning!
# Estimated fps : 21.22836181389906
# predict_gesture: Doing_other_things
# Estimated fps : 23.088581242160153
# predict_gesture: Doing_other_things
# Estimated fps : 20.287781035039014
# predict_gesture: Doing_other_things
# Estimated fps : 21.599549040329816
# predict_gesture: Doing_other_things
# Estimated fps : 22.520492223331807
# predict_gesture: Doing_other_things
# Estimated fps : 23.014670454845252
# predict_gesture: Doing_other_things
# Estimated fps : 23.087065019665843
# predict_gesture: Doing_other_things
# Estimated fps : 21.296645848351982
# predict_gesture: Doing_other_things
# Estimated fps : 20.654898712165892
# predict_gesture: Doing_other_things
# Estimated fps : 22.82979745832644
# predict_gesture: Doing_other_things
# Estimated fps : 21.6065846808145
# predict_gesture: Doing_other_things
# Estimated fps : 21.80153916753457
# predict_gesture: Doing_other_things
# Estimated fps : 22.628482972137263
# predict_gesture: Doing_other_things
# Estimated fps : 23.295270216542338
# predict_gesture: Doing_other_things
# Estimated fps : 22.576750428653934
# predict_gesture: Doing_other_things
# Estimated fps : 22.820165132609542
# predict_gesture: Doing_other_things
# Estimated fps : 22.81468574580401
# predict_gesture: Doing_other_things
# Estimated fps : 22.268574939510525
# predict_gesture: Doing_other_things
# Estimated fps : 22.292438413496395
# predict_gesture: Doing_other_things
# Estimated fps : 22.488655335861434
# predict_gesture: Doing_other_things
# Estimated fps : 22.57849036973123
# predict_gesture: Doing_other_things
# Estimated fps : 22.40909844215981
# predict_gesture: Doing_other_things
# Estimated fps : 23.015423794279172
# predict_gesture: Doing_other_things
# Estimated fps : 19.68536488401024
# predict_gesture: Zooming_In
# cleaning!
# Estimated fps : 22.22633934780542
# predict_gesture: Doing_other_things
# Estimated fps : 20.062940135821766
# predict_gesture: Doing_other_things
# Estimated fps : 22.652102757068267
# predict_gesture: Doing_other_things
# Estimated fps : 21.535114639419493
# predict_gesture: Doing_other_things
# Estimated fps : 22.483477760367794
# predict_gesture: Doing_other_things
# Estimated fps : 22.982173208168412
# predict_gesture: Doing_other_things
# Estimated fps : 22.77094519758254
# predict_gesture: Doing_other_things
# Estimated fps : 22.751787782890997
# predict_gesture: Doing_other_things
# Estimated fps : 23.051793325028193
# predict_gesture: Doing_other_things
# Estimated fps : 22.75797357569742
# predict_gesture: Doing_other_things
# Estimated fps : 23.1385762613692
# predict_gesture: Doing_other_things
# Estimated fps : 22.84166379707976
# predict_gesture: Doing_other_things
# Estimated fps : 20.273274052545617
# predict_gesture: Zooming_In
# cleaning!
# Estimated fps : 19.288240393267955
# predict_gesture: Doing_other_things
# Estimated fps : 21.843938537246142
# predict_gesture: Doing_other_things
# Estimated fps : 22.124371471903736
# predict_gesture: Doing_other_things
# Estimated fps : 18.748921396610882
# predict_gesture: Doing_other_things
# Estimated fps : 22.111152341539512
# predict_gesture: Doing_other_things
# Estimated fps : 22.149461640718616
# predict_gesture: Doing_other_things
# Estimated fps : 22.535938872185923
# predict_gesture: Doing_other_things
# Estimated fps : 23.091007612428548
# predict_gesture: Doing_other_things
# Estimated fps : 22.25461946028892
# predict_gesture: Doing_other_things
# Estimated fps : 21.84882571920413
# predict_gesture: Doing_other_things
# Estimated fps : 22.74045589205544
# predict_gesture: Doing_other_things
# Estimated fps : 23.10709520523142
# predict_gesture: Doing_other_things
# Estimated fps : 22.27252511941873
# predict_gesture: Doing_other_things
# Estimated fps : 23.13020336462698
# predict_gesture: Doing_other_things
# Estimated fps : 22.830983537357493
# predict_gesture: Doing_other_things
# Estimated fps : 21.114762073499953
# predict_gesture: Doing_other_things
# Estimated fps : 22.330244286641072
# predict_gesture: Doing_other_things
# Estimated fps : 20.067062798954435
# predict_gesture: Doing_other_things
# Estimated fps : 22.26194742941128
# predict_gesture: Doing_other_things
# Estimated fps : 23.054060788878257
# predict_gesture: Doing_other_things
# Estimated fps : 21.648095123739274
# predict_gesture: Doing_other_things
# Estimated fps : 22.507948397836014
# predict_gesture: Doing_other_things
# Estimated fps : 23.01647855234869
# predict_gesture: Doing_other_things
# Estimated fps : 22.252365671026475
# predict_gesture: Doing_other_things
# Estimated fps : 22.529006914493053
# predict_gesture: Doing_other_things
# Estimated fps : 22.024438680900083
# predict_gesture: Doing_other_things
# Estimated fps : 22.88776260880472
# predict_gesture: Doing_other_things
# Estimated fps : 23.602745887880705
# predict_gesture: Zooming_In
# cleaning!
# Estimated fps : 22.03189195964297
# predict_gesture: Doing_other_things
# Estimated fps : 22.289752986230774
# predict_gesture: Doing_other_things
# Estimated fps : 21.807218976019538
# predict_gesture: Doing_other_things
# Estimated fps : 21.762402040287746
# predict_gesture: Doing_other_things
# Estimated fps : 22.477009142638487
# predict_gesture: Doing_other_things
# Estimated fps : 22.610146055347823
# predict_gesture: Doing_other_things
# Estimated fps : 21.19777026090059
# predict_gesture: Doing_other_things
# Estimated fps : 22.06203248155317
# predict_gesture: Doing_other_things
# Estimated fps : 20.42925131327967
# predict_gesture: Doing_other_things
# Estimated fps : 22.537817011568446
# predict_gesture: Doing_other_things
# Estimated fps : 21.55029545900231
# predict_gesture: Doing_other_things
# Estimated fps : 22.80832111484311
# predict_gesture: Doing_other_things
# Estimated fps : 22.56226134168581
# predict_gesture: Doing_other_things
# Estimated fps : 21.57741006929272
# predict_gesture: Doing_other_things
# Estimated fps : 22.814537690788526
# predict_gesture: Doing_other_things
# Estimated fps : 20.48376740663386
# predict_gesture: Doing_other_things
# Estimated fps : 20.51041672744069
# predict_gesture: Doing_other_things
# Estimated fps : 22.75797357569742
# predict_gesture: Doing_other_things
# Estimated fps : 21.86322846251327
# predict_gesture: Swiping_Up
# cleaning!
# Estimated fps : 22.519626683060007
# predict_gesture: Doing_other_things
# Estimated fps : 22.60796506841928
# predict_gesture: Doing_other_things
# Estimated fps : 21.350838090615515
# predict_gesture: Doing_other_things
# Estimated fps : 22.87034218059112
# predict_gesture: Doing_other_things
# Estimated fps : 21.296516840320884
# predict_gesture: Doing_other_things
# Estimated fps : 22.74648835058067
# predict_gesture: Doing_other_things
# Estimated fps : 22.80033335062419
# predict_gesture: Doing_other_things
# Estimated fps : 21.08576141066323
# predict_gesture: Doing_other_things
# Estimated fps : 23.392924157943213
# predict_gesture: Doing_other_things
# Estimated fps : 23.089794363554905
# predict_gesture: Doing_other_things
# Estimated fps : 22.582261162244432
# predict_gesture: Doing_other_things
# Estimated fps : 22.004450174934327
# predict_gesture: Doing_other_things
# Estimated fps : 16.707357525755288
# predict_gesture: Doing_other_things
# Estimated fps : 21.659698605155654
# predict_gesture: Doing_other_things
# Estimated fps : 22.625424754158285
# predict_gesture: Doing_other_things
# Estimated fps : 23.886919240652038
# predict_gesture: Doing_other_things
# Estimated fps : 22.0703425156262
# predict_gesture: Zooming_Out
# cleaning!
# Estimated fps : 20.749743256803782
# predict_gesture: Doing_other_things
# Estimated fps : 21.28555686737262
# predict_gesture: Doing_other_things
# Estimated fps : 22.01120085149168
# predict_gesture: Doing_other_things
# Estimated fps : 22.469826153653678
# predict_gesture: Doing_other_things
# Estimated fps : 22.459060274062573
# predict_gesture: Doing_other_things
# Estimated fps : 21.627053894939515
# predict_gesture: Doing_other_things
# Estimated fps : 22.587774586712882
# predict_gesture: Doing_other_things
# Estimated fps : 21.141935328680738
# predict_gesture: Doing_other_things
# Estimated fps : 23.036688290417672
# predict_gesture: Doing_other_things
# Estimated fps : 23.034122402984313
# predict_gesture: Doing_other_things
# Estimated fps : 21.803567330885777
# predict_gesture: Doing_other_things
# Estimated fps : 22.741485597479784
# predict_gesture: Doing_other_things
# Estimated fps : 23.028539799824426
# predict_gesture: Doing_other_things
# Estimated fps : 21.529311981386464
# predict_gesture: Doing_other_things
# Estimated fps : 23.32138616357511
# predict_gesture: Doing_other_things
# Estimated fps : 23.026880628791275
# predict_gesture: Doing_other_things
# Estimated fps : 22.237867823792097
# predict_gesture: Doing_other_things
# Estimated fps : 20.030590326644734
# predict_gesture: Doing_other_things
# Estimated fps : 22.28791596138332
# predict_gesture: Doing_other_things
# Estimated fps : 23.039103765551072
# predict_gesture: Doing_other_things
# Estimated fps : 22.49354745832848
# predict_gesture: Doing_other_things
# Estimated fps : 21.306455034152574
# predict_gesture: Doing_other_things
# Estimated fps : 23.554040654433013
# predict_gesture: Doing_other_things
# Estimated fps : 21.073501291758525
# predict_gesture: Doing_other_things
# Estimated fps : 21.59729329590339
# predict_gesture: Doing_other_things
# Estimated fps : 23.305771372507238
# predict_gesture: Doing_other_things
# Estimated fps : 23.026578987009955
# predict_gesture: Doing_other_things
# Estimated fps : 22.069095611454895
# predict_gesture: Doing_other_things
# Estimated fps : 22.542586002377274
# predict_gesture: Doing_other_things
# Estimated fps : 22.25955121630179
# predict_gesture: Doing_other_things
# Estimated fps : 23.037594034225876
# predict_gesture: Doing_other_things
# Estimated fps : 22.760920373689483
# predict_gesture: Doing_other_things
# Estimated fps : 21.7989707022153
# predict_gesture: Doing_other_things
# Estimated fps : 22.036725483434534
# predict_gesture: Doing_other_things
# Estimated fps : 21.829425644206555
# predict_gesture: Doing_other_things
# Estimated fps : 22.904165010782158
# predict_gesture: Doing_other_things
# Estimated fps : 22.752818514827847
# predict_gesture: Doing_other_things
# Estimated fps : 22.326557181323984
# predict_gesture: Doing_other_things
# Estimated fps : 21.54501274697669
# predict_gesture: Doing_other_things
# Estimated fps : 22.765931682048915
# predict_gesture: Doing_other_things
# Estimated fps : 22.053867048071098
# predict_gesture: Doing_other_things
# Estimated fps : 23.02507089667441
# predict_gesture: Doing_other_things
# Estimated fps : 22.272666223188157
# predict_gesture: Doing_other_things
# Estimated fps : 19.30656525440037
# predict_gesture: Doing_other_things
# Estimated fps : 22.746488350573316
# predict_gesture: Doing_other_things
# Estimated fps : 22.063970929724743
# predict_gesture: Doing_other_things
# Estimated fps : 21.997703637888797
# predict_gesture: Doing_other_things
# Estimated fps : 20.24583782040298
# predict_gesture: Doing_other_things
# Estimated fps : 17.725800921675276
# predict_gesture: Doing_other_things
# Estimated fps : 22.018093567988938
# predict_gesture: Doing_other_things
# Estimated fps : 23.01617718302908
# predict_gesture: Doing_other_things
# Estimated fps : 21.564836283783617
# predict_gesture: Doing_other_things
# Estimated fps : 22.504778609242557
# predict_gesture: Doing_other_things
# Estimated fps : 21.97707666533734
# predict_gesture: Doing_other_things
# Estimated fps : 21.443430579023723
# predict_gesture: Doing_other_things
# Estimated fps : 20.722835249040227
# predict_gesture: Doing_other_things
# Estimated fps : 20.048066833942553
# predict_gesture: Doing_other_things
# Estimated fps : 22.06023279891954
# predict_gesture: Doing_other_things
# Estimated fps : 22.829204465024535
# predict_gesture: Doing_other_things
# Estimated fps : 20.42699599667952
# predict_gesture: Doing_other_things
# Estimated fps : 22.56008958250936
# predict_gesture: Doing_other_things
# Estimated fps : 20.505751081971248
# predict_gesture: Doing_other_things
# Estimated fps : 18.908957423463807
# predict_gesture: Doing_other_things
# Estimated fps : 18.774854207165834
# predict_gesture: Doing_other_things
# Estimated fps : 19.680956832801034
# predict_gesture: Doing_other_things
# Estimated fps : 22.495706424366222
# predict_gesture: Doing_other_things
# Estimated fps : 23.043785190378557
# predict_gesture: Doing_other_things
# Estimated fps : 22.497433895616066
# predict_gesture: Doing_other_things
# Estimated fps : 21.837154410440288
# predict_gesture: Doing_other_things
# Estimated fps : 19.43345715454512
# predict_gesture: Doing_other_things
# Estimated fps : 22.52987317598236
# predict_gesture: Doing_other_things
# Estimated fps : 23.03382057145397
# predict_gesture: Doing_other_things
# Estimated fps : 19.82512462499425
# predict_gesture: Doing_other_things
